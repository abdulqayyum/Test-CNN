# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation, Convolution2D, MaxPooling2D, BatchNormalization,AtrousConvolution2D
from IPython.display import SVG
from keras.utils.visualize_util import model_to_dot

# %%
model = Sequential()
#Conv Layer 1
model.add(Convolution2D(64,3,3, border_mode='same',input_shape=(3,224,224)))
model.add(Activation('relu'))
model.add(Convolution2D(64,3,3, subsample=(2,2)))
model.add(Activation('relu'))
model.add(BatchNormalization(epsilon=1e-05,axis=1,momentum=0.99))

# %%
#Conv Layer 2
model.add(Convolution2D(128,3,3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(128,3,3,subsample=(2,2)))
model.add(Activation('relu'))
model.add(BatchNormalization(epsilon=1e-05,momentum=0.99,weights=None,beta_init='zero',gamma_init='one',gamma_regularizer=None,beta_regularizer=None))

# %%
#Conv Layer 3
model.add(Convolution2D(256,3,3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(256,3,3))
model.add(Activation('relu'))
model.add(Convolution2D(256,3,3,subsample=(2,2)))
model.add(Activation('relu'))
model.add(BatchNormalization(epsilon=1e-05,momentum=0.99,weights=None,beta_init='zero',gamma_init='one',gamma_regularizer=None,beta_regularizer=None))

# %%
#Conv Layer 4
model.add(AtrousConvolution2D(512,3,3,atrous_rate=(1,1),border_mode='same',subsample=(1,1)))
model.add(Activation('relu'))
model.add(AtrousConvolution2D(512,3,3,atrous_rate=(1,1),border_mode='same',subsample=(1,1)))
model.add(Activation('relu'))
model.add(AtrousConvolution2D(512,3,3,atrous_rate=(1,1),border_mode='same',subsample=(1,1)))
model.add(Activation('relu'))
model.add(BatchNormalization(epsilon=1e-05,momentum=0.99,weights=None,beta_init='zero',gamma_init='one',gamma_regularizer=None,beta_regularizer=None))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_15 (Convolution2D) (None, 3, 224, 64)    129088      convolution2d_input_3[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 3, 224, 64)    0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 1, 111, 64)    36928       activation_21[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 1, 111, 64)    0           convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNormal(None, 1, 111, 64)    2           activation_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 1, 111, 128)   73856       batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 1, 111, 128)   0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 0, 55, 128)    147584      activation_23[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 0, 55, 128)    0           convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorma(None, 0, 55, 128)    256         activation_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D) (None, 0, 55, 256)    295168      batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 0, 55, 256)    0           convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D) (None, -2, 53, 256)   590080      activation_25[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, -2, 53, 256)   0           convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D) (None, -2, 26, 256)   590080      activation_26[0][0]
# ____________________________________________________________________________________________________
# activation_27 (Activation)       (None, -2, 26, 256)   0           convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorma(None, -2, 26, 256)   512         activation_27[0][0]
# ____________________________________________________________________________________________________
# atrousconvolution2d_7 (AtrousConv(None, -2, 26, 512)   1180160     batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, -2, 26, 512)   0           atrousconvolution2d_7[0][0]
# ____________________________________________________________________________________________________
# atrousconvolution2d_8 (AtrousConv(None, -2, 26, 512)   2359808     activation_28[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, -2, 26, 512)   0           atrousconvolution2d_8[0][0]
# ____________________________________________________________________________________________________
# atrousconvolution2d_9 (AtrousConv(None, -2, 26, 512)   2359808     activation_29[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, -2, 26, 512)   0           atrousconvolution2d_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorma(None, -2, 26, 512)   1024        activation_30[0][0]
# ====================================================================================================
# Total params: 7764354
# ____________________________________________________________________________________________________

# %%
SVG(model_to_dot(model,show_shapes='true').create(prog='dot', format='svg'))
